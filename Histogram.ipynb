# %% [markdown]
# # Demonstration of Drawing Graphs

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
hist, bins = np.histogram(x, bins=50)
width = 0.5 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width)
plt.show()

# %%
bins[:-1]
# Out:
# array([  39.65484149,   42.058734  ,   44.46262651,   46.86651902,
#          49.27041153,   51.67430404,   54.07819656,   56.48208907,
#          58.88598158,   61.28987409,   63.6937666 ,   66.09765911,
#          68.50155162,   70.90544413,   73.30933664,   75.71322915,
#          78.11712166,   80.52101417,   82.92490668,   85.32879919,
#          87.7326917 ,   90.13658421,   92.54047672,   94.94436923,
#          97.34826175,   99.75215426,  102.15604677,  104.55993928,
#         106.96383179,  109.3677243 ,  111.77161681,  114.17550932,
#         116.57940183,  118.98329434,  121.38718685,  123.79107936,
#         126.19497187,  128.59886438,  131.00275689,  133.4066494 ,
#         135.81054191,  138.21443443,  140.61832694,  143.02221945,
#         145.42611196,  147.83000447,  150.23389698,  152.63778949,
#         155.041682  ,  157.44557451])

# %%
bins[1:]
# Out:
# array([  42.058734  ,   44.46262651,   46.86651902,   49.27041153,
#          51.67430404,   54.07819656,   56.48208907,   58.88598158,
#          61.28987409,   63.6937666 ,   66.09765911,   68.50155162,
#          70.90544413,   73.30933664,   75.71322915,   78.11712166,
#          80.52101417,   82.92490668,   85.32879919,   87.7326917 ,
#          90.13658421,   92.54047672,   94.94436923,   97.34826175,
#          99.75215426,  102.15604677,  104.55993928,  106.96383179,
#         109.3677243 ,  111.77161681,  114.17550932,  116.57940183,
#         118.98329434,  121.38718685,  123.79107936,  126.19497187,
#         128.59886438,  131.00275689,  133.4066494 ,  135.81054191,
#         138.21443443,  140.61832694,  143.02221945,  145.42611196,
#         147.83000447,  150.23389698,  152.63778949,  155.041682  ,
#         157.44557451,  159.84946702])

# %%
bins[1], bins[0]
# Out:
# (42.05873400239328, 39.654841491827469)

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('IQ results')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([30, 160, 0, 0.035])
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.random.normal(size = 1000)
plt.hist(x, normed=True, bins=30) # bin = slice size
plt.ylabel('Probability');

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.random.normal(size = 1000)
plt.hist(x, normed=False, bins=30)
plt.ylabel('Probability');

# %%
x = np.arange(3)
plt.bar(x, height= [4,2,3])
plt.xticks(x, ['a','b','c']);

# %%
v = [0,5,9,10,15]

# %%
w = [0,1,2,3,4]

# %%
plt.plot(v,w)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

s = [0,5,9,10,15]
r = [0,1,2,3,4]
plt.plot(s,r)
plt.xticks(np.arange(min(s), max(s)+1, 3.0)) # you can change the slice
plt.show()
